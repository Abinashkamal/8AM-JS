# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Welcome_To_Colab_question1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Advanced_pandas_sales_dataset.csv")
df.dtypes
# Out:
# Order_ID        int64
# Order_Date     object
# Customer       object
# City           object
# Region         object
# Product        object
# Category       object
# Sales           int64
# Quantity        int64
# Discount      float64
# Profit        float64
# dtype: object

# %% [markdown]
# Question 1 - Perform the following exploratory steps:
# Display the first 10 rows
# Display the dataset structure using info()
# Find the number of rows and columns
# Identify the data types of each column
