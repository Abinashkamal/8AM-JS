# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Welcome_To_Colab_Question7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Advanced_pandas_sales_dataset.csv")
df.pivot_table(index='Region', columns='Product', values='Sales', aggfunc='sum')
df[df['Product'] == 'Laptop'].groupby('Region')['Sales'].sum().idxmax()
# Out:
# 'East'

# %% [markdown]
# Q7 Pivot Table Creation
# Create a pivot table showing:
# Rows → Region
# Columns → Product
# Values → Total Sales
# Which region sells the most laptops
