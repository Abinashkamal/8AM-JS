# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Welcome_To_Colab_Question4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Advanced_pandas_sales_dataset.csv")
df.groupby('Region')['Sales'].sum()
df.groupby('Region')['Sales'].sum().idxmax()
# Out:
# 'East'

# %% [markdown]
# Q4 Regional Sales Performance
# Calculate the total sales generated by each region.
# Then identify:
# Which region generated the highest revenue?
