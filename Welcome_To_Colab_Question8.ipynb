# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Welcome_To_Colab_Question8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Advanced_pandas_sales_dataset.csv")
df.groupby('Category')['Profit'].mean()
df.groupby('Category')['Profit'].mean().idxmax()
# Out:
# 'Office'

# %% [markdown]
# Q8 Profitability Analysis
# Calculate the average profit for each product category.
# Which category is most profitable
# ---
