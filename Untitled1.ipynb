# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1. Create a Python dictionary with the required columns and 5 rows of data
sales_data = {
    'Product': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Tablet'],
    'Region': ['North', 'South', 'East', 'West', 'Central'],
    'Sales': [1200, 25, 45, 300, 450],
    'Quantity': [5, 50, 40, 15, 20]
}

# 2. Convert the dictionary into a Pandas DataFrame
df = pd.DataFrame(sales_data)

# 3. Display the DataFrame (this generates the required output)
df
# Out:
#     Product   Region  Sales  Quantity
# 0    Laptop    North   1200         5
# 1     Mouse    South     25        50
# 2  Keyboard     East     45        40
# 3   Monitor     West    300        15
# 4    Tablet  Central    450        20

# %% [markdown]
# ### Q1. Creating a DataFrame
# **Question Statement:**
# Create a Pandas DataFrame using a Python dictionary with the following columns:
# * Product
# * Region
# * Sales
# * Quantity
