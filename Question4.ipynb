# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Question4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filtered_data = df_retail[df_retail['Region'] == 'South']
filtered_data

selected_columns = df_retail[['Product', 'Sales']]
selected_columns
# Out:
#      Product  Sales
# 0     Laptop   1056
# 1     Tablet    904
# 2     Laptop   1597
# 3   Keyboard    777
# 4      Phone   2028
# ..       ...    ...
# 85    Laptop   1330
# 86  Keyboard    741
# 87   Monitor    875
# 88    Tablet   2213
# 89    Laptop   1270
#
# [90 rows x 2 columns]

# %% [markdown]
# Using .loc, perform the following:
# Display the row with index 10.
# Display the Sales value of the row with index 20
