# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinashkamal/8AM-JS/blob/main/Question4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
selected_data = df_retail.iloc[10:16, :]

selected_data
# Out:
#     Order_ID Customer  Product Region  Sales  Quantity
# 10      1011      Raj  Monitor  North   1693         6
# 11      1012    Rahul   Laptop   East   1022         5
# 12      1013    Meera   Tablet  North   1191         5
# 13      1014    Rohan    Phone  South   2078         3
# 14      1015    Sneha   Laptop   West    813         6
# 15      1016    Karan  Monitor   West    796         3

# %% [markdown]
# ### Q4. Data Selection using .iloc
# **Question Statement:**
# [Type the exact instructions from your screenshot here]

# %% [markdown]
# Using .loc, perform the following:
# Display the row with index 10.
# Display the Sales value of the row with index 20
